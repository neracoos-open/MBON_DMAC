# %%
import pandas as pd
import plotly.graph_objects as go
import os
import numpy as np

# %%
# Load data 
root_dir = "results/"
target_prefix = "WBTS"

WBTS_CI_GAM_prediction = pd.read_csv(f"{root_dir}WBTS_CI_GAM_prediction.csv")
# WBTS_CI_seasonal_predictions = pd.read_csv(f"{root_dir}WBTS_CI_seasonal_predictions.csv")

# WBTS_CSI_GAM_prediction = pd.read_csv(f"{root_dir}WBTS_CSI_GAM_prediction.csv")
# WBTS_CSI_seasonal_predictions = pd.read_csv(f"{root_dir}WBTS_CSI_seasonal_predictions.csv")

# WBTS_DW_GAM_prediction = pd.read_csv(f"{root_dir}WBTS_DW_GAM_prediction.csv")
# WBTS_DW_seasonal_predictions = pd.read_csv(f"{root_dir}WBTS_DW_seasonal_predictions.csv")

#df_all = pd.concat([pd.read_csv(os.path.join(root_dir, f)) for f in os.listdir(root_dir) if f.startswith(target_prefix)])

# %%
WBTS_CI_GAM_prediction.head()
# Out:
#    day_of_year  year  prediction  standard_error
# 0            1  2005  172.163615       21.184610
# 1            2  2005  171.161578       21.164153
# 2            3  2005  170.136147       21.125260
# 3            4  2005  169.087138       21.067442
# 4            5  2005  168.014956       20.991589

# %%
# Plot the data
fig = go.Figure(data=go.Scatter(
    x=WBTS_CI_GAM_prediction['day_of_year'],
    y=np.log10((WBTS_CI_GAM_prediction['prediction'] + 1) * (WBTS_CI_GAM_prediction['prediction'] + 1)**3),
    mode='markers',
    name='MARMAP 2x mean'
))

fig.update_layout(
    title='Climatology of Calanus finmarchicus abundance - Wilkinson Basin - Gulf of Maine',
    xaxis_title='Day of Year',
    yaxis_title='Abundance [log10(inds+1)m^3]',
    legend_title='Series'
)

fig.update_layout(dropdown=[
    dict(label="Select Year", method="relayout",
         args=[{"xaxis.title.text": "Year: "}, {"yaxis.title.text": "Abundance [log10(inds+1)m^3]"}]),
    dict(label=str(WBTS_CI_GAM_prediction["year"].min()), method="relayout"),
    dict(label=str(WBTS_CI_GAM_prediction["year"].max()), method="relayout")
])





# fig.add_trace(go.Scatter(
#     x=df_all['day_of_year'],
#     y=df_all['prediction'],
#     mode='lines',
#     name='MARMAP Climatology (mean)'
# ))

# fig.add_trace(go.Scatter(
#     x=df_all['day_of_year'],
#     y=df_all['prediction'],
#     mode='lines',
#     name='WBTS 2005-2024'
# ))

# # Customize the plot
# fig.update_layout(
#     title='Climatology of Calanus finmarchicus abundance - Wilkinson Basin - Gulf of Maine',
#     xaxis_title='day_of_year',
#     yaxis_title='prediction',
#     legend_title='Series'
# )

# Visualize the plot
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 16
#       2 fig = go.Figure(data=go.Scatter(
#       3     x=WBTS_CI_GAM_prediction['day_of_year'],
#       4     y=np.log10((WBTS_CI_GAM_prediction['prediction'] + 1) * (WBTS_CI_GAM_prediction['prediction'] + 1)**3),
#       5     mode='markers',
#       6     name='MARMAP 2x mean'
#       7 ))
#       9 fig.update_layout(
#      10     title='Climatology of Calanus finmarchicus abundance - Wilkinson Basin - Gulf of Maine',
#      11     xaxis_title='Day of Year',
#      12     yaxis_title='Abundance [log10(inds+1)m^3]',
#      13     legend_title='Series'
#      14 )
# ---> 16 fig.update_layout(dropdown=[
#      17     dict(label="Select Year", method="relayout",
#      18          args=[{"xaxis.title.text": "Year: "}, {"yaxis.title.text": "Abundance [log10(inds+1)m^3]"}]),
# ...
